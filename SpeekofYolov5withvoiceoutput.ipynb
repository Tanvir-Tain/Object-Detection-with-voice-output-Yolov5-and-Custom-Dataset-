# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.0+cu111 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.9/107.7 GB disk)

# %%
# !pip install gTTS

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CjhXSYYCsGvb4yKRbOTo")
project = rf.workspace().project("taka-dataset")
dataset = project.version(1).download("yolov5")

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
from re import S
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/zidane.jpg

#display.Image(filename='runs/detect/exp2/bus.jpg', width=600)
#sound_file = '1.wav'
#Audio(sound_file, autoplay=True)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images/zidane.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/1 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.253s)
# finally we get ['2 person', 'tain', '2 tie']
# Speed: 4.9ms pre-process, 253.0ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp13

# %%
# !python detect.py
# Out:
# detect: weights=yolov5s.pt, source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# tain ['1 bus', '4 person']
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, Done. (0.282s)
# tain ['2 tie', '1 bus', '4 person', '2 person']
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.227s)
# finally we get ['2 tie', '1 bus', '4 person', '2 person']
# Speed: 2.1ms pre-process, 254.3ms inference, 1.8ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
# !python detect.py --source 'https://www.youtube.com/watch?v=o9_tRbUKMmM'
#sound_file = '1.wav'
#Audio(sound_file, autoplay=True)
# Out:
# detect: weights=yolov5s.pt, source=https://www.youtube.com/watch?v=o9_tRbUKMmM, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-21-ge6e36aa torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# WARNING: Environment does not support cv2.imshow() or PIL Image.show() image displays
# cv2.imshow() is disabled in Google Colab environments
# 1/1: https://www.youtube.com/watch?v=o9_tRbUKMmM...  Success (1704 frames 640x360 at 23.89 FPS)
#
# tain ['1 person']
# 0: 384x640 1 person, Done. (0.225s)
# tain ['1 frisbee', '1 person']
# 0: 384x640 1 person, 1 frisbee, Done. (0.228s)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data data.yaml --weights yolov5x.pt --cache

# %%
model=torch.hub.load('ultralytics/yolov5','yolov5s')
#Image
img = 'https://ultralytics.com/images/zidane.jpg'
#Inference
results = model(img)

labels, cord_thres = results.xyxyn[0][:, -1].numpy(), results.xyxyn[0][:, :-1].numpy()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#
# requirements: 1 package updated per /content/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v6.1-0-g3752807 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# Adding AutoShape...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-8335497cd52c> in <module>()
#       5 results = model(img)
#       6
# ----> 7 labels, cord_thres = results.xyxyn[0][:, -1].numpy(), results.xyxyn[0][:, :-1].numpy()
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-275a67dad426> in <module>()
# ----> 1 results.print()
#
# NameError: name 'results' is not defined

# %%
from gtts import gTTS
from IPython.display import Audio
trf="ki re bishu munshi , ki khobor . five hundred taka dhar de"
ft="are beta "+ trf
tts = gTTS(ft)
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio
trf="ki re bishu munshi , ki khobor . five hundred taka dhar de"
ft="are beta "+ trf
tts = gTTS(ft)
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
